# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../input/iris-flower-dataset/IRIS.csv")

# %%
subset = df[['species', 'petal_length', 'petal_width']]
df1=subset.groupby("species")

# %%
subset.groupby("species").mean()
# Out:
#                  petal_length  petal_width
# species
# Iris-setosa             1.464        0.244
# Iris-versicolor         4.260        1.326
# Iris-virginica          5.552        2.026

# %%
subset.groupby("species").agg([np.min, np.mean, np.median, np.max])
# Out:
#                 petal_length                    petal_width
#                         amin   mean median amax        amin   mean median amax
# species
# Iris-setosa              1.0  1.464   1.50  1.9         0.1  0.244    0.2  0.6
# Iris-versicolor          3.0  4.260   4.35  5.1         1.0  1.326    1.3  1.8
# Iris-virginica           4.5  5.552   5.55  6.9         1.4  2.026    2.0  2.5

# %%
subset.mean()
# Out:
# petal_length    3.758667
# petal_width     1.198667
# dtype: float64

# %%
subset.median()
# Out:
# petal_length    4.35
# petal_width     1.30
# dtype: float64

# %%
subset.var()
# Out:
# petal_length    3.113179
# petal_width     0.582414
# dtype: float64

# %%
subset.max()
# Out:
# species         Iris-virginica
# petal_length               6.9
# petal_width                2.5
# dtype: object

# %%
subset.min()
# Out:
# species         Iris-setosa
# petal_length              1
# petal_width             0.1
# dtype: object

# %%
max=subset.groupby("species").max()
max
# Out:
#                  petal_length  petal_width
# species
# Iris-setosa               1.9          0.6
# Iris-versicolor           5.1          1.8
# Iris-virginica            6.9          2.5

# %%
min=subset.groupby("species").min()
min
# Out:
#                  petal_length  petal_width
# species
# Iris-setosa               1.0          0.1
# Iris-versicolor           3.0          1.0
# Iris-virginica            4.5          1.4

# %%
subset.describe()
# Out:
#        petal_length  petal_width
# count    150.000000   150.000000
# mean       3.758667     1.198667
# std        1.764420     0.763161
# min        1.000000     0.100000
# 25%        1.600000     0.300000
# 50%        4.350000     1.300000
# 75%        5.100000     1.800000
# max        6.900000     2.500000

# %%
subset.groupby("species").describe()
# Out:
#                 petal_length                                               \
#                        count   mean       std  min  25%   50%    75%  max
# species
# Iris-setosa             50.0  1.464  0.173511  1.0  1.4  1.50  1.575  1.9
# Iris-versicolor         50.0  4.260  0.469911  3.0  4.0  4.35  4.600  5.1
# Iris-virginica          50.0  5.552  0.551895  4.5  5.1  5.55  5.875  6.9
#
#                 petal_width
#                       count   mean       std  min  25%  50%  75%  max
# species
# Iris-setosa            50.0  0.244  0.107210  0.1  0.2  0.2  0.3  0.6
# Iris-versicolor        50.0  1.326  0.197753  1.0  1.2  1.3  1.5  1.8
# Iris-virginica         50.0  2.026  0.274650  1.4  1.8  2.0  2.3  2.5

# %%
max-min
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-c062f869bb14> in <module>
# ----> 1 subset.iloc[:,:1].apply(max-min)
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    6876             kwds=kwds,
#    6877         )
# -> 6878         return op.get_result()
#    6879
#    6880     def applymap(self, func) -> "DataFrame":
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/apply.py in get_result(self)
#     147         # dispatch to agg
#     148         if is_list_like(self.f) or is_dict_like(self.f):
# --> 149             return self.obj.aggregate(self.f, axis=self.axis, *self.args, **self.kwds)
#     150
#     151         # all empty
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py in aggregate(self, func, axis, *args, **kwargs)
#    6704         result = None
# ...
